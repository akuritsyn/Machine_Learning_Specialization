# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
results = []
with open('checkins.dat') as inputfile:
    for line in inputfile:
        results.append(line.strip().split(','))

# %%
import csv

# %%
fileRead = open("checkins.dat", "r")

# %%
csvReader = csv.reader(fileRead)

# %%
header = csvReader.next()

# %%
header
# Out:
# ['   id    | user_id | venue_id |     latitude      |     longitude     |     created_at      ']

# %%
a, b, c, d, e, f = header[0].split('|', 5)

# %%
print a,b,c
# Out:
#    id      user_id   venue_id

# %%
header = csvReader.next()

# %%
header
# Out:
# ['  984301 | 2041916 |     5222 |                   |                   | 2012-04-21 17:39:01']

# %%
mylist = header[0].split('|')

# %%
mylist
# Out:
# ['  984301 ',
#  ' 2041916 ',
#  '     5222 ',
#  '                   ',
#  '                   ',
#  ' 2012-04-21 17:39:01']

# %%
mylist
# Out:
# ['(1021966 rows)']

# %%
len(coordList)
# Out:
# 396634

# %%
coordList = []
fileRead = open("checkins.dat", "r")
fileSave = open('checkins.csv', 'w')
csvReader = csv.reader(fileRead)

header = csvReader.next()
index=header[0].split('|')

fileSave.write(",".join(index).replace(" ", "")+'\n')

header = csvReader.next()

for row in csvReader:
    mylist = row[0].split('|')
    if mylist[3] != '                   ' and  mylist[4] != '                   ':
        s = list(mylist[5])
        s[11]='T'
        #print s
        mylist[5]="".join(s)
        #coordList.append(",".join(mylist).replace(" ", ""))
        fileSave.write(",".join(mylist).replace(" ", "")+'\n')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-107-dc0760f1efdf> in <module>()
#      13 for row in csvReader:
#      14     mylist = row[0].split('|')
# ---> 15     if mylist[3] != '                   ' and  mylist[4] != '                   ':
#      16         s = list(mylist[5])
#      17         s[11]='T'
#
# IndexError: list index out of range

# %%
fileRead.close()
fileSave.close()

# %%
df = pd.read_csv('checkins.csv')

# %%
df.head()
# Out:
#        id  user_id  venue_id   latitude   longitude           created_at
# 0  984222    15824      5222  38.895112  -77.036366  2012-04-21T17:43:47
# 1  984234    44652      5222  33.800745  -84.410520  2012-04-21T17:43:43
# 2  984291   105054      5222  45.523452 -122.676207  2012-04-21T17:39:22
# 3  984318  2146539      5222  40.764462 -111.904565  2012-04-21T17:35:46
# 4  984232    93870    380645  33.448377 -112.074037  2012-04-21T17:38:18

# %%
df.shape
# Out:
# (396634, 6)

# %%
X=df.ix[0:100000-1,3:5].values
#DataFrame.as_matrix

# %%
len(X)
# Out:
# 100000

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth

# %%
centers = np.array([[33.751277, -118.188740], [25.867736, -80.324116], [51.503016, -0.075479], [52.378894, 4.885084], [39.366487, 117.036146], [-33.868457, 151.205134]])

# %%
centers.shape[0]
# Out:
# 6L

# %%
ms = MeanShift(bandwidth=0.1, bin_seeding=True,min_bin_freq=16)
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_


labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)
# Out:
# number of estimated clusters : 499

# %%
cluster_centers[0,1]
# Out:
# -73.991835419896702

# %%
cluster_centers
# Out:
# array([[  4.07177164e+01,  -7.39918354e+01],
#        [  3.34463803e+01,  -1.11901888e+02],
#        [  3.34484105e+01,  -1.12074004e+02],
#        [  4.18782438e+01,  -8.76298434e+01],
#        [  3.76886816e+01,  -1.22409330e+02],
#        [  3.88861652e+01,  -7.70487833e+01],
#        [  3.33573446e+01,  -1.11822654e+02],
#        [  3.37666362e+01,  -8.43932892e+01],
#        [  4.23632186e+01,  -7.10736876e+01],
#        [  4.76062447e+01,  -1.22332044e+02],
#        [  3.61172291e+01,  -1.15171073e+02],
#        [  3.40603976e+01,  -1.18248709e+02],
#        [  4.49779478e+01,  -9.32673009e+01],
#        [  3.02671836e+01,  -9.77431193e+01],
#        [  3.97358302e+01,  -1.04986580e+02],
#        [  4.07674307e+01,  -7.38191906e+01],
#        [  3.99516804e+01,  -7.51627359e+01],
#        [  3.40354870e+01,  -1.18438998e+02],
#        [  3.29808934e+01,  -1.17078118e+02],
#        [  3.28030205e+01,  -9.67698974e+01],
#        [  2.85435015e+01,  -8.13764286e+01],
# ...

# %%
len(cluster_centers)
# Out:
# 499

# %%
minDist=1e10
x_coord=-1
y_coord=-1
for i in range(centers.shape[0]):
    for j in range(len(cluster_centers)):
        distClust=((centers[i,0]-cluster_centers[j,0])**2+(centers[i,1]-cluster_centers[j,1])**2)**0.5
        if distClust<minDist:
            minDist=distClust
            x_coord=cluster_centers[j,0]
            y_coord=cluster_centers[j,1]
            print minDist,x_coord,y_coord,j
# Out:
# 44.7425709178 40.7177163973 -73.9918354199 0
# 6.29424146275 33.4463802704 -111.901887562 1
# 6.12223170534 33.4484104925 -112.074004279 2
# 5.77204797983 37.6886815741 -122.409330374 4
# 3.83458486854 36.117229143 -115.171073423 10
# 0.314883790336 34.0603975546 -118.248709027 11
# 0.304097540309 33.8112331402 -117.890611546 26
# 0.211810536824 33.8729860116 -118.362091147 42
# 0.0647631884186 33.8064645507 -118.154848927 54
# 0.022358439052 25.8830503775 -80.30782583 286
# 0.00935331618599 52.3729639903 4.89231722258 345
# 0.00783475816311 -33.8606304286 151.204775929 378

# %%
cluster_centers[378,:]
# Out:
# array([ -33.86063043,  151.20477593])
